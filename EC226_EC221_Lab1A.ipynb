# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io.wavfile import write
from scipy.io.wavfile import read

# %% [markdown]
# ## Question 1
#
# Plot the Following signals from $n = -20$ to $n = 20$. Use the command
# stem to plot the signals. Clearly mark the time origin in each case.
# \begin{equation}\nonumber
# (i)~~(\frac{1}{3})^nu[n]-2^nu[−n-5]
# \end{equation}
# \begin{equation}\nonumber
#  (ii)~~~~~~~~~~~~3\sin(\pi\frac{n}{4}+\frac{\pi}{3})
# \end{equation}
# \begin{equation}\nonumber
#  (iii)~~~~~~~~~~~3\sin(3\pi\frac{n}{4}+\frac{\pi}{3})
# \end{equation}
# (what is the difference from above signal? Why?)
#
# \begin{equation}\nonumber
#  (iv)~~~~~~~~~~~~e^{-0.1n}\cos(\frac{n\pi}{8})
# \end{equation}
# \begin{equation}\nonumber
#  (v)~~~~~~~~~~~~~~~~~~~\frac{\sin(\frac{n\pi}{6})}{\frac{n\pi}{6}}
# \end{equation}

# %%
x = np.arange(-20,21,0.2)

y1 = (np.power(1/3, x)*np.heaviside(x,1)) - (np.power(2, x)*np.heaviside(-x-5,1))
plt.grid()
plt.stem(x,y1,use_line_collection=True)
# Out:
# /var/folders/hk/rvywyngd2vlf6_zb7q0zr_wh0000gp/T/ipykernel_47970/1395578060.py:5: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x,y1,use_line_collection=True)
# <StemContainer object of 3 artists>

# %%
y2 = 3*np.sin((np.pi*x/4)+(np.pi/3))
plt.grid()
plt.stem(x, y2,use_line_collection=True)
# Out:
# /var/folders/hk/rvywyngd2vlf6_zb7q0zr_wh0000gp/T/ipykernel_47970/1246033515.py:3: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x, y2,use_line_collection=True)
# <StemContainer object of 3 artists>

# %%
y3 = 3*np.sin((3*np.pi*x/4)+(np.pi/3))
plt.grid()
plt.stem(x, y3,use_line_collection=True)

# y3 different from y2 in the way such that the frequency of y3 is 3 times that of y2
# Out:
# /var/folders/hk/rvywyngd2vlf6_zb7q0zr_wh0000gp/T/ipykernel_47970/1603547413.py:3: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x, y3,use_line_collection=True)
# <StemContainer object of 3 artists>

# %%
y4 = np.exp(-0.1*x)*np.cos(np.pi*x/8)
plt.grid()
plt.stem(x, y4,use_line_collection=True)
# Out:
# /var/folders/hk/rvywyngd2vlf6_zb7q0zr_wh0000gp/T/ipykernel_47970/361786965.py:3: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x, y4,use_line_collection=True)
# <StemContainer object of 3 artists>

# %%
y5 = (np.sin(x*np.pi/6))/(x*np.pi/6)
plt.grid()
plt.stem(x, y5,use_line_collection=True)
# Out:
# /var/folders/hk/rvywyngd2vlf6_zb7q0zr_wh0000gp/T/ipykernel_47970/4038054738.py:3: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x, y5,use_line_collection=True)
# <StemContainer object of 3 artists>

# %% [markdown]
# ## Question 2
# Suppose you sample an analog signal $x(t)=1-t$ during the interval $0\leqslant t \leqslant 1 sec$ with a
# sampling period of $0.125$ to generate $x[n]$. Plot $x[n]$, $x[-n]$, $x_{even}[n]$ and $x_{odd}[n]$.

# %%
n1b = np.arange(0, 1.125, 0.125)

y1bp = 1 - n1b
y1bn = 1 + n1b
y1be = (y1bp + y1bn) / 2
y1bo = (y1bp - y1bn)/2

# %%
plt.grid()
plt.stem(n1b, y1bp,use_line_collection=True)
# Out:
# /var/folders/hk/rvywyngd2vlf6_zb7q0zr_wh0000gp/T/ipykernel_47970/1625578681.py:2: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n1b, y1bp,use_line_collection=True)
# <StemContainer object of 3 artists>

# %%
plt.grid()
plt.stem(n1b, y1bn,use_line_collection=True)
# Out:
# /var/folders/hk/rvywyngd2vlf6_zb7q0zr_wh0000gp/T/ipykernel_47970/1241680097.py:2: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n1b, y1bn,use_line_collection=True)
# <StemContainer object of 3 artists>

# %%
plt.grid()
plt.stem(n1b, y1be,use_line_collection=True)
# Out:
# /var/folders/hk/rvywyngd2vlf6_zb7q0zr_wh0000gp/T/ipykernel_47970/2142930115.py:2: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n1b, y1be,use_line_collection=True)
# <StemContainer object of 3 artists>

# %%
plt.grid()
plt.stem(n1b, y1bo,use_line_collection=True)
# Out:
# /var/folders/hk/rvywyngd2vlf6_zb7q0zr_wh0000gp/T/ipykernel_47970/1314008160.py:2: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n1b, y1bo,use_line_collection=True)
# <StemContainer object of 3 artists>

# %% [markdown]
# ## Question 3
# Let $x[n]=[2, 4, -3, \textbf{1}, -5, 4, 7]$ $-3\leqslant n \leqslant 3$. Generate and plot the samples of the
# following sequences using stem function.
#
# \begin{equation}\nonumber
# (i)~~~~x_{1}[n] = 2x[n-3] + 3x[n + 4] - x[n]
# \end{equation}
# \begin{equation}\nonumber
# (ii)~~~~~~~~~~~x_{2}[n] = x[-n- 4] + x[-n + 4]
# \end{equation}
# \begin{equation}\nonumber
# (iii)~~~~~~~~~~~~~~x_{3}[n] = 2e^{0.5n} x[n] u[-n-1]
# \end{equation}

# %%
n1c = np.arange(-3,4,1)
    
x1c=[]
x2c=[]
x3c=[]

xc = {-7:0, -6:0, -5:0, -4:0, -3:2, -2:4, -1:-3, 0:1, 1:-5, 2:4, 3:7, 4:0, 5:0, 6:0, 7:0}
for i in n1c:
    x1c.append(2*xc[i-3]+3*xc[i+4]-xc[i])
    x2c.append(xc[-i-4]+xc[-i+4])
    x3c.append(2*np.exp(0.5*i)*xc[i]*np.heaviside(-i-1,1))

# %%
plt.grid()
plt.stem(n1c, x1c,use_line_collection=True)
# Out:
# /var/folders/hk/rvywyngd2vlf6_zb7q0zr_wh0000gp/T/ipykernel_47970/3052885276.py:2: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n1c, x1c,use_line_collection=True)
# <StemContainer object of 3 artists>

# %%
plt.grid()
plt.stem(n1c, x2c,use_line_collection=True)
# Out:
# /var/folders/hk/rvywyngd2vlf6_zb7q0zr_wh0000gp/T/ipykernel_47970/2239251994.py:2: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n1c, x2c,use_line_collection=True)
# <StemContainer object of 3 artists>

# %%
plt.grid()
plt.stem(n1c, x3c,use_line_collection=True)
# Out:
# /var/folders/hk/rvywyngd2vlf6_zb7q0zr_wh0000gp/T/ipykernel_47970/2592212310.py:2: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n1c, x3c,use_line_collection=True)
# <StemContainer object of 3 artists>

# %% [markdown]
# ## Question 4
# Consider the discrete time signal $x[n]=\cos(\frac{2\pi n}{7})$. \
# (i) Obtain and plot the downsampled (decimated) signal $y[n]=x[2n]$ along with $x[n]$\
# (ii) Obtain and plot the upsampled (interpolated) signal $z[n]=x[n/2]$ for $n$ even and $z[n]=0$ otherwise along with $x[n]$

# %%
n1d = np.arange(-5,6,1)

xd = np.cos(2*np.pi*n1d/7)
yd = np.cos(4*np.pi*n1d/7)

yd,xd

zd=[]
for i in n1d:
    if(i%2==0):
        zd.append(np.cos(1*np.pi*i/7))
    else:
        zd.append(0)

# %%
plt.subplot(2, 1, 1)
plt.stem(n1d, xd,'r', markerfmt='ro', label='original' ,use_line_collection=True)
plt.legend()

plt.subplot(2, 1, 2)
plt.stem(n1d, yd, 'b', markerfmt='bo', label='decimated' ,use_line_collection=True)
plt.legend()
# Out:
# /var/folders/hk/rvywyngd2vlf6_zb7q0zr_wh0000gp/T/ipykernel_47970/4029854286.py:2: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n1d, xd,'r', markerfmt='ro', label='original' ,use_line_collection=True)
# /var/folders/hk/rvywyngd2vlf6_zb7q0zr_wh0000gp/T/ipykernel_47970/4029854286.py:6: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n1d, yd, 'b', markerfmt='bo', label='decimated' ,use_line_collection=True)

# %%
plt.subplot(2, 1, 1)
plt.stem(n1d, xd,'r', markerfmt='ro', label='original' ,use_line_collection=True)
plt.legend()

plt.subplot(2, 1, 2)
plt.stem(n1d, zd,'b', markerfmt='bo', label='interpolated' ,use_line_collection=True)
plt.legend()
# Out:
# /var/folders/hk/rvywyngd2vlf6_zb7q0zr_wh0000gp/T/ipykernel_47970/1963442794.py:2: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n1d, xd,'r', markerfmt='ro', label='original' ,use_line_collection=True)
# /var/folders/hk/rvywyngd2vlf6_zb7q0zr_wh0000gp/T/ipykernel_47970/1963442794.py:6: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n1d, zd,'b', markerfmt='bo', label='interpolated' ,use_line_collection=True)

# %% [markdown]
# ## Question 5
# Generate the following signals with the specified sampling rate and listen to it.
# Let $t$ vary from $0 - 3$seconds.  Let the sampling rate is 8000Hz or a sampling time period is $125 \mu s$
# (A sample is taken at every integer multiple of $125 \mu s$ )
#
# $x(t) = sin(100\pi t)$ (100 Hz sinusoid)\
# $x(t) = cos(1000\pi t)$ (1kHz sinusoid) \
# $x(t) = sin(100 \pi t^2) $  (Called a chirp signal) \
#
# To listen to a signal, write the signal to a file using wave write command  from scipy
# Please look up the documentation here\ (https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.io.wavfile.write.html).   Then download the signal and listen to it.

# %%
samplerate = 8000
t = np.linspace(0., 3., 3*samplerate)

amplitude = np.iinfo(np.int16).max

x1ea = amplitude * np.sin(2. * np.pi * 50 * t)
x1eb = amplitude * np.cos(2. * np.pi * 500 * t)
x1ec = amplitude * np.sin(2. * np.pi * 50 * t * t)

write("QE1.wav", samplerate, x1ea.astype(np.int16))
write("QE2.wav", samplerate, x1eb.astype(np.int16))
write("QE3.wav", samplerate, x1ec.astype(np.int16))

# %% [markdown]
# ## Question 6
# Sample the signal $cos ( 10 \pi t)$ using the following frequencies (a) 20 Hz (b) 7.5 Hz (c) 5 Hz (d) 2.5 Hz.   In each case, plot the signal and determine its period.

# %%
samplerate = 20
t = np.arange(0, 1, 1/samplerate)

plt.subplot(2,2,1)
xf = np.cos(10 * np.pi * t)
plt.grid()
plt.stem(t,xf)


samplerate = 7.5
t = np.arange(0, 1, 1/samplerate)

plt.subplot(2,2,2)
xf = np.cos(10 * np.pi * t)
plt.grid()
plt.stem(t,xf)


samplerate = 5
t = np.arange(0, 1, 1/samplerate)

plt.subplot(2,2,3)
xf = np.cos(10 * np.pi * t)
plt.grid()
plt.stem(t,xf)


samplerate = 2.5
t = np.arange(0, 1, 1/samplerate)

plt.subplot(2,2,4)
xf = np.cos(10 * np.pi * t)
plt.grid()
plt.stem(t,xf)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# ## Question 7
# In DTMF dialling a number is represented by a dual frequency tone. Do a web search and find the frequencies
# of each digit. Generate DTMF tones corresponding to the telephone number $08242474040$ by sampling the sum of sinusoids
# at the required frequencies at $Fs= 8192$ Hz. Concatenate the signals by putting 50 zeros between each signal
# (to represent silence) and listen to the signal. (Must sound like tone dialling the same number from a phone)

# %%
fs=8192
t = np.arange(0, 0.5, 1/fs)

tones = {
    0: np.sin(2*np.pi*941*t) + np.sin(2*np.pi*1336*t),
    2: np.sin(2*np.pi*697*t) + np.sin(2*np.pi*1336*t),
    4: np.sin(2*np.pi*770*t) + np.sin(2*np.pi*1209*t),
    7: np.sin(2*np.pi*852*t) + np.sin(2*np.pi*1209*t),
    8: np.sin(2*np.pi*852*t) + np.sin(2*np.pi*1336*t)
}

x00 = []
xs = []
for i in range(0,50):
    x00.append(0)

for i in [0,8,2,4,2,4,7,4,0,4,0]:
        xs = np.concatenate((xs,tones[i],x00))

write("QEx.wav", fs, xs)

# %% [markdown]
# ## Question 8
# Record your own voice for half a minute and observe the time domain waveform
# (Use any sound recording program, save in $*.wav~~format$ and read it using wavread command in Python for further processing).\
# (i) Find the sampling rate used by the recorder(one of the outputs of wavread)\
# (ii) Compare with the quality of the a standard speech recording (available in moodle)\
# (iii) Find the max/min/average values and energy of the entire signal \
# (iv) Split the signal into segments of $20ms$ long and compute the energy of each segment and plot it. \
# (v) Quantize the above recorded file to (i) Single bit (ii) $4$ Bits (iii) $16$ bits and listen to it.
#      Observe the quantization noise.

# %%
fs, data = read("./keerthi.wav")
data = data.astype('float64')
print(len(data))

print(f'Sampling Rate -> {fs} Hz')
print('Maximum Value -> ',np.amax(data))
print('Minimum Value -> ',np.amin(data))
print('Average Value -> ',np.average(data))

energy = np.sum(data.astype("float64")**2)
print('Energy -> ',energy)

sizeSeg = int(fs*0.02)
segs = [data[i:i+sizeSeg] for i in range(0, len(data), sizeSeg)]
segEnergy = [np.sum(seg.astype("float64")**2) for seg in segs]

plt.plot(segEnergy)
# Out:
# 1364631
# Sampling Rate -> 44100 Hz
# Maximum Value ->  24048.0
# Minimum Value ->  -21048.0
# Average Value ->  0.5261986573659839
# Energy ->  24916386731554.0

# %%
signal_max = np.amax(data)
signal_min = np.amin(data)

q_steps = (signal_max - signal_min) / (2**1)
qs = q_steps * np.round(data / q_steps)
write("1b'Quantised.wav",fs,qs)

q_steps = (signal_max - signal_min) / (2**4)
qs = q_steps * np.round(data / q_steps)
write("4b'Quantise.wav",fs,qs)

q_steps = (signal_max - signal_min) / (2**16)
qs = q_steps * np.round(data / q_steps)
write("16b'Quantise.wav",fs,qs)

# %% [markdown]
# ## Question 9
# A coarse way to approximate a musical note is to generate a set of harmonics
# (integer multiples of a base frequency) and perform a weighted sum with an amplitude that is slowly
# starting and stopping. Here we try to generate the following approximation to a musical note:
#
# \begin{equation}\nonumber
#  x[n] = \sin(\omega n) + \alpha \sin(2\omega n) + \alpha^2\sin(2\omega n)
# \end{equation}
# \begin{equation}\nonumber
#  w[n] =e^{-\beta_{1}n}(1-e^{-\beta_{2}n})
# \end{equation}
# \begin{equation}\nonumber
#  y[n] =w[n]x[n]
# \end{equation}
#
#
# Start with parameters: $\omega=0.2742830$, $\alpha=0.5$, $\beta_{1}=1e-4$ and $\beta_{2}=1e-3$. Generate $8000$ samples
# $(n = 0......7999)$ of the signal and save the signal as $.wav$ file with sampling frequency $16000$Hz.
# (ie., a note of length $0.5$s)

# %%
fs = 16000

omega = 0.2742830
alpha = 0.5
beta1 = 1e-4
beta2 = 1e-3

n = np.arange(8000)

x = np.sin(omega * n) + alpha * np.sin(2 * omega * n) + alpha * alpha * np.sin(2 * omega * n)
w = np.exp(-beta1 * n) * (1 - np.exp(-beta2 * n))
y = w * x

write("QE9.wav", fs, y)
