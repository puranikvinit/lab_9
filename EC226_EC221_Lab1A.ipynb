# %% [markdown]
# ## Question 1
#
# (1) Plot the Following signals from $n = -20$ to $n = 20$. Use the command
# stem to plot the signals. Clearly mark the time origin in each case.
# \begin{equation}\nonumber
# (i)~~(\frac{1}{3})^nu[n]-2^nu[−n-5]
# \end{equation}
# \begin{equation}\nonumber
#  (ii)~~~~~~~~~~~~3\sin(\pi\frac{n}{4}+\frac{\pi}{3})
# \end{equation}
# \begin{equation}\nonumber
#  (iii)~~~~~~~~~~~3\sin(3\pi\frac{n}{4}+\frac{\pi}{3})
# \end{equation}
# (what is the difference from above signal? Why?)
#
# \begin{equation}\nonumber
#  (iv)~~~~~~~~~~~~e^{-0.1n}\cos(\frac{n\pi}{8})
# \end{equation}
# \begin{equation}\nonumber
#  (v)~~~~~~~~~~~~~~~~~~~\frac{\sin(\frac{n\pi}{6})}{\frac{n\pi}{6}}
# \end{equation}

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-20,21,0.2)

# %%
def step(x):
    if x>=0:
        return 1
    return 0

# def f(y):
#     return (((1/3)**y)*step(y))-((2**y)*step(y-5))
# l = []
# for i in x:
#     l.append(f(i))

# %%
y1 = (np.power(1/3, x)*np.heaviside(x,1)) - (np.power(2, x)*np.heaviside(x-5,1))

# %%
plt.grid()
plt.stem(x,y1, basefmt="")
# Out:
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# <StemContainer object of 3 artists>

# %%
y2 = 3*np.sin((np.pi*x/4)+(np.pi/3))
plt.grid()
plt.stem(x, y2)
# Out:
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# <StemContainer object of 3 artists>

# %%
y3 = 3*np.sin((3*np.pi*x/4)+(np.pi/3))
plt.grid()
plt.stem(x, y3)

# y3 different from y2 in the way such that the frequency of y3 is 3 times that of y2
# Out:
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# <StemContainer object of 3 artists>

# %%
y4 = np.exp(-0.1*x)*np.cos(np.pi*x/8)
plt.grid()
plt.stem(x, y4)
# Out:
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# <StemContainer object of 3 artists>

# %%
y5 = (np.sin(x*np.pi/6))/(x*np.pi/6)
plt.grid()
plt.stem(x, y5)
# Out:
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# <StemContainer object of 3 artists>

# %% [markdown]
# ## Question 1B
# (2) Suppose you sample an analog signal $x(t)=1-t$ during the interval $0\leqslant t \leqslant 1 sec$ with a
# sampling period of $0.125$ to generate $x[n]$. Plot $x[n]$, $x[-n]$, $x_{even}[n]$ and $x_{odd}[n]$.

# %%
n1b = np.arange(0, 1.125, 0.125)

# def x(t):
#     return 1 - t

y1bp=[]
y1bn=[]
y1bo=[]
y1be=[]

y1bp = 1 - n1b
y1bn = np.flip(y1bp)
y1be = 1 + np.zeros([9],dtype=int)
y1bo = (y1bp - y1bn)/2

# for i in n1b:
#     y1bp.append(x(i))
#     y1bn.append(x(-i))
#     y1be.append((x(i)+x(-i))/2)
#     y1bo.append((x(i)-x(-i))/2)

# %%
plt.grid()
plt.stem(n1b, y1bp)
# Out:
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# <StemContainer object of 3 artists>

# %%
plt.grid()
plt.stem(n1b, y1bn)
# Out:
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# <StemContainer object of 3 artists>

# %%
plt.grid()
plt.stem(n1b, y1be)
# Out:
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# <StemContainer object of 3 artists>

# %%
plt.grid()
plt.stem(n1b, y1bo)
# Out:
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# <StemContainer object of 3 artists>

# %% [markdown]
# ## Question 1C
# (3) Let $x[n]=[2, 4, -3, \textbf{1}, -5, 4, 7]$ $-3\leqslant n \leqslant 3$. Generate and plot the samples of the
# following sequences using stem function.
#
# \begin{equation}\nonumber
# (i)~~~~x_{1}[n] = 2x[n-3] + 3x[n + 4] - x[n]
# \end{equation}
# \begin{equation}\nonumber
# (ii)~~~~~~~~~~~x_{2}[n] = x[-n- 4] + x[-n + 4]
# \end{equation}
# \begin{equation}\nonumber
# (iii)~~~~~~~~~~~~~~x_{3}[n] = 2e^{0.5n} x[n] u[-n-1]
# \end{equation}

# %%
n1c = np.arange(-3,4,1)
n1c

# def xc(n):
#     if(n==-3):
#         return 2
#     elif(n==-2):
#         return 4
#     elif(n==-1):
#         return -3
#     elif(n==0):
#         return 1
#     elif(n==1):
#         return -5
#     elif(n==2):
#         return 4
#     elif(n==3):
#         return 7
#     else:
#         return 0
    
x1c=[]
x2c=[]
x3c=[]

# for i in n1c:
#     x1c.append(2*xc(i-3)+3*xc(i+4)-xc(i))
#     x2c.append(xc(-i-4)+xc(-i+4))
#     x3c.append(2*np.exp(0.5*i)*xc(i)*step(-i-1))

# %%
xc = {-7:0, -6:0, -5:0, -4:0, -3:2, -2:4, -1:-3, 0:1, 1:-5, 2:4, 3:7, 4:0, 5:0, 6:0, 7:0}
for i in n1c:
    x1c.append(2*xc[i-3]+3*xc[i+4]-xc[i])
    x2c.append(xc[-i-4]+xc[-i+4])
    x3c.append(2*np.exp(0.5*i)*xc[i]*step(-i-1))

# %%
plt.grid()
plt.stem(n1c, x1c)
# Out:
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# <StemContainer object of 3 artists>

# %%
plt.grid()
plt.stem(n1c, x2c)
# Out:
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# <StemContainer object of 3 artists>

# %%
plt.grid()
plt.stem(n1c, x3c)
# Out:
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# <StemContainer object of 3 artists>

# %% [markdown]
# ## Question 1D
# (4) Consider the discrete time signal $x[n]=\cos(\frac{2\pi n}{7})$. \
# (i) Obtain and plot the downsampled (decimated) signal $y[n]=x[2n]$ along with $x[n]$\
# (ii) Obtain and plot the upsampled (interpolated) signal $z[n]=x[n/2]$ for $n$ even and $z[n]=0$ otherwise along with $x[n]$

# %%
n1d = np.arange(-5,5,1)

xd = np.cos(2*np.pi*n1d/7)
yd = np.cos(4*np.pi*n1d/7)

yd,xd
# Out:
# (array([-0.90096887,  0.6234898 ,  0.6234898 , -0.90096887, -0.22252093,
#          1.        , -0.22252093, -0.90096887,  0.6234898 ,  0.6234898 ]),
#  array([-0.22252093, -0.90096887, -0.90096887, -0.22252093,  0.6234898 ,
#          1.        ,  0.6234898 , -0.22252093, -0.90096887, -0.90096887]))

# %%
zd=[]
for i in n1d:
    if(i%2==0):
        zd.append(np.cos(1*np.pi*i/7))
    else:
        zd.append(0)
        
zd
# Out:
# [0,
#  -0.22252093395631434,
#  0,
#  0.6234898018587336,
#  0,
#  1.0,
#  0,
#  0.6234898018587336,
#  0,
#  -0.22252093395631434]

# %%
plt.stem(n1d, xd,'r', markerfmt='ro', label='original')
plt.stem(n1d, yd, 'b', markerfmt='bo', label='decimated')
plt.legend()
# Out:
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
plt.stem(n1d, xd,'r', markerfmt='ro', label='original')
plt.stem(n1d, zd,'b', markerfmt='bo', label='interpolated')
plt.legend()
# Out:
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %% [markdown]
# ## Question 1E
# (5) Generate the following signals with the specified sampling rate and listen to it.
# Let $t$ vary from $0 - 3$seconds.  Let the sampling rate is 8000Hz or a sampling time period is $125 \mu s$
# (A sample is taken at every integer multiple of $125 \mu s$ )
#
# $x(t) = sin(100\pi t)$ (100 Hz sinusoid)\
# $x(t) = cos(1000\pi t)$ (1kHz sinusoid) \
# $x(t) = sin(100 \pi t^2) $  (Called a chirp signal) \
#
# To listen to a signal, write the signal to a file using wave write command  from scipy
# Please look up the documentation here\ (https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.io.wavfile.write.html).   Then download the signal and listen to it.

# %%
from scipy.io.wavfile import write
import numpy as np
samplerate = 8000
t = np.linspace(0., 3., 3*samplerate)
amplitude = np.iinfo(np.int16).max
x1ea = amplitude * np.sin(2. * np.pi * 50 * t)
x1eb = amplitude * np.cos(2. * np.pi * 500 * t)
x1ec = amplitude * np.sin(2. * np.pi * 50 * t * t)
write("QE1.wav", samplerate, x1ea.astype(np.int16))
write("QE2.wav", samplerate, x1eb.astype(np.int16))
write("QE3.wav", samplerate, x1ec.astype(np.int16))

# %% [markdown]
# ## Question 1F
# (6) Sample the signal $cos ( 10 \pi t)$ using the following frequencies (a) 20 Hz (b) 7.5 Hz (c) 5 Hz (d) 2.5 Hz.   In each case, plot the signal and determine its period.

# %%
samplerate = 20
t = np.arange(0, 1, 1/samplerate)
plt.subplot(2,2,1)
xf = np.cos(10 * np.pi * t)
plt.grid()
plt.stem(t,xf)

samplerate = 7.5
t = np.linspace(0., 1., samplerate+1)
plt.subplot(2,2,2)
xf = np.cos(10 * np.pi * t)
plt.grid()
plt.stem(t,xf)

samplerate = 5
t = np.linspace(0., 1., samplerate+1)
plt.subplot(2,2,3)
xf = np.cos(10 * np.pi * t)
plt.grid()
plt.stem(t,xf)

samplerate = 2.5
t = np.linspace(0., 1., samplerate+1)
plt.subplot(2,2,4)
xf = np.cos(10 * np.pi * t)
plt.grid()
plt.stem(t,xf)
# Out:
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   if __name__ == '__main__':
# /home/dsdlab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   del sys.path[0]
# ...

# %% [markdown]
# ## Question 1g
# (7) In DTMF dialling a number is represented by a dual frequency tone. Do a web search and find the frequencies
# of each digit. Generate DTMF tones corresponding to the telephone number $08242474040$ by sampling the sum of sinusoids
# at the required frequencies at $Fs= 8192$ Hz. Concatenate the signals by putting 50 zeros between each signal
# (to represent silence) and listen to the signal. (Must sound like tone dialling the same number from a phone)

# %%
fs=8192
tone_freq_hash = {}
